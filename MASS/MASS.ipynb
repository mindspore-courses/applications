# %% [markdown]
# # pip

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # download punkt

# %%
import nltk
nltk.download('punkt')

# %% [markdown]
# # 如果无法下载，执行下列命令

# %% [raw]
# cd ..
# mkdir nltk_data
# mkdir nltk_data/tokenizers
# cp work/punkt.zip nltk_data/tokenizers
# cd nltk_data/tokenizers
# unzip punkt.zip

# %% [markdown]
# # tokenizer

# %%
import os
from nltk.tokenize import word_tokenize

data_list = ['news_crawl','ggw_data']
src_folder = "./dataset/"
out_folder = "./tokenized_corpus/"

if not os.path.isdir(out_folder):
    os.mkdir(out_folder)
if not os.path.isdir(out_folder+'news_crawl/'):
    os.mkdir(out_folder+'news_crawl/')
if not os.path.isdir(out_folder+'ggw_data/'):
    os.mkdir(out_folder+'ggw_data/')

def create_tokenized_sentences(file_path, tokenized_file):
    tokenized_sen = []
    print(f" | Processing {file_path}.")
    with open(file_path, "r") as file:
        for sen in file:
            tokens = word_tokenize(sen)
            tokens = [t for t in tokens if t != " "]
            if len(tokens) > 175:
                continue
            tokenized_sen.append(" ".join(tokens) + "\n")

    with open(tokenized_file, "w") as file:
        file.writelines(tokenized_sen)
    print(f" | Wrote to {tokenized_file}.")

for item in data_list:
    folder_path = os.path.join(src_folder, item)
    output_path = os.path.join(out_folder, item)
    for file in os.listdir(folder_path):
        if not file.endswith(".txt"):
            continue
        file_path = os.path.join(folder_path, file)
        tokenized_file = os.path.join(output_path, file.replace(".txt", "_tokenized.txt"))
        create_tokenized_sentences(file_path, tokenized_file)
# Out:
#  | Processing ./dataset/news_crawl/news2012_short.txt.
#  | Wrote to ./tokenized_corpus/news_crawl/news2012_short_tokenized.txt.
#  | Processing ./dataset/ggw_data/test.tgt.txt.
#  | Wrote to ./tokenized_corpus/ggw_data/test.tgt_tokenized.txt.
#  | Processing ./dataset/ggw_data/train_short.tgt.txt.
#  | Wrote to ./tokenized_corpus/ggw_data/train_short.tgt_tokenized.txt.
#  | Processing ./dataset/ggw_data/test.src.txt.
#  | Wrote to ./tokenized_corpus/ggw_data/test.src_tokenized.txt.
#  | Processing ./dataset/ggw_data/train_short.src.txt.
#  | Wrote to ./tokenized_corpus/ggw_data/train_short.src_tokenized.txt.

# %% [markdown]
# # learn bpe

# %%
if not os.path.isdir('./vocab/'):
    os.mkdir('./vocab/')

import subprocess
commands = "cat ./dataset/ggw_data/*.txt ./dataset/news_crawl/*.txt | subword-nmt learn-bpe -s 46000 -o ./vocab/all.bpe.codes"

subprocess.call(commands,shell=True)
# Out:
# 0

# %% [markdown]
# # vocab

# %%
import os
import subprocess
from src.utils import Dictionary

source_folder = os.path.abspath("./tokenized_corpus/news_crawl/")
output_folder = os.path.abspath("./tokenized_corpus/news_crawl/bpe/")
codes = os.path.abspath("./vocab/all.bpe.codes")
vocab_path = "./vocab/all_en.dict.bin"

if not os.path.isdir(output_folder):
    os.mkdir(output_folder)

ENCODER = "subword-nmt apply-bpe -c"
LEARN_DICT = "subword-nmt get-vocab -i"
def bpe_encode(codes_path, src_path, output_path, dict_path):
    # Encoding.
    print(" | Applying BPE encoding.")
    commands = ENCODER.split() + [codes_path] + ["-i"] + [src_path] + ["-o"] + [output_path]
    subprocess.call(commands)
    print(" | Fetching vocabulary from single file.")
    # Learn vocab.
    commands = LEARN_DICT.split() + [output_path] + ["-o"] + [dict_path]
    subprocess.call(commands)

available_dict = []
for file in os.listdir(source_folder):
    if file.endswith(".txt"):
        output_path = os.path.join(output_folder, file.replace(".txt", "_bpe.txt"))
        dict_path = os.path.join(output_folder, file.replace(".txt", ".dict"))
        available_dict.append(dict_path)
        bpe_encode(codes, os.path.join(source_folder, file), output_path, dict_path)

# 加载bpe_encode處理過的文本词汇表，行格式为[word, freq]。
vocab = Dictionary.load_from_text(available_dict)
vocab.persistence(vocab_path) #将词汇表对象保存为二进制文件。
print(f" | Vocabulary Size: {len(vocab)}")
# Out:
#  | Applying BPE encoding.
#  | Fetching vocabulary from single file.
#  | Vocabulary Size: 36469

# %% [markdown]
# # creat dataset nc

# %%
"""Create News Crawl Pre-Training Dataset."""
import os
from src.dataset import MonoLingualDataLoader
from src.language_model import LooseMaskedLanguageModel
from src.utils import Dictionary

input_folder_path = './dataset/news_crawl/' # Raw corpus folder
output_folder_path = './train_data/news_crawl/' # Dataset output path

if not os.path.isdir(output_folder_path):
    os.mkdir('./train_data')
    os.mkdir('./train_data/news_crawl/')

vocab_path = './vocab/all_en.dict.bin' # Existed vocab path
vocab = Dictionary.load_from_persisted_dict(vocab_path)

def create_pre_train(text_file, output_folder, vocab, max_sen_len):

    loader = MonoLingualDataLoader(
        src_filepath=text_file,
        lang="en", dictionary=vocab,
        language_model=LooseMaskedLanguageModel(mask_ratio=0.5, mask_all_prob=None),
        max_sen_len=max_sen_len, min_sen_len=10
    )

    src_file_name = os.path.basename(text_file)

    file_name = os.path.join(
        output_folder_path,
        src_file_name.replace('.txt', f'_len_{max_sen_len}.mindrecord')
    )

    if os.path.exists(file_name):
        os.remove(file_name)
    if os.path.exists(file_name+'.db'):
        os.remove(file_name+'.db')

    loader.write_to_mindrecord(path=file_name)

for file in os.listdir(input_folder_path):
    if file.endswith(".txt"):
        create_pre_train(os.path.join(input_folder_path, file),output_folder_path, vocab, 32)

print(f" | Generate Dataset for Pre-training is done.")
print(f" | Vocabulary size: {vocab.size}.")
# Out:
#  | Processing corpus ./dataset/news_crawl/news2012_short.txt.
#  | Shortest len = 1.
#  | Longest  len = 1090.
#  | Total    sen = 999745.
# | Wrote to /home/ma-user/work/MASS-ms200/train_data/news_crawl/news2012_short_len_32.mindrecord.
#  | Generate Dataset for Pre-training is done.
#  | Vocabulary size: 36469.

# %% [markdown]
# # create dataset ggw

# %%
"""Generate Gigaword dataset."""
import os
from src.dataset import BiLingualDataLoader
from src.language_model import NoiseChannelLanguageModel
from src.utils import Dictionary

input_folder_path = './dataset/ggw_data/'
output_folder_path = './train_data/ggw_data/'

if not os.path.isdir(output_folder_path):
    os.mkdir('./train_data/ggw_data/')

vocab_path = './vocab/all_en.dict.bin'
vocab = Dictionary.load_from_persisted_dict(vocab_path)

train = BiLingualDataLoader(
    src_filepath=os.path.join(input_folder_path,"train_short.src.txt"),
    tgt_filepath=os.path.join(input_folder_path,"train_short.tgt.txt"),
    src_dict=vocab, tgt_dict=vocab,
    src_lang="en", tgt_lang="en",
    language_model=NoiseChannelLanguageModel(add_noise_prob=0),
    max_sen_len=32
)

train_path = os.path.join(output_folder_path, "gigaword_train_dataset.mindrecord")
if os.path.exists(train_path):
        os.remove(train_path)
if os.path.exists(train_path+'.db'):
        os.remove(train_path+'.db')

train.write_to_mindrecord(
    path=train_path
)

test = BiLingualDataLoader(
    src_filepath=os.path.join(input_folder_path,"test.src.txt"),
    tgt_filepath=os.path.join(input_folder_path,"test.tgt.txt"),
    src_dict=vocab, tgt_dict=vocab,
    src_lang="en", tgt_lang="en",
    language_model=NoiseChannelLanguageModel(add_noise_prob=0),
    max_sen_len=32
)

test_path = os.path.join(output_folder_path, "gigaword_test_dataset.mindrecord")
if os.path.exists(test_path):
        os.remove(test_path)
if os.path.exists(test_path+'.db'):
        os.remove(test_path+'.db')

test.write_to_mindrecord(
    path=test_path
)

print(f" | Generate Dataset for fine-tuneing is done.")
print(f" | Vocabulary size: {vocab.size}.")
# Out:
#  | Processing corpus ./dataset/ggw_data/train_short.src.txt.
#  | Processing corpus ./dataset/ggw_data/train_short.tgt.txt.
#  | Shortest len = 4.
#  | Longest  len = 90.
#  | Total    sen = 194181.
#  | Total token num=8755897, 10.717634069930243% replaced by <unk>.
# | Wrote to /home/ma-user/work/MASS-ms200/train_data/ggw_data/gigaword_train_dataset.mindrecord.
#  | Processing corpus ./dataset/ggw_data/test.src.txt.
#  | Processing corpus ./dataset/ggw_data/test.tgt.txt.
#  | Shortest len = 2.
#  | Longest  len = 73.
#  | Total    sen = 1081.
#  | Total token num=46933, 10.191123516502248% replaced by <unk>.
# | Wrote to /home/ma-user/work/MASS-ms200/train_data/ggw_data/gigaword_test_dataset.mindrecord.
#  | Generate Dataset for fine-tuneing is done.
#  | Vocabulary size: 36469.

# %% [markdown]
# # load data

# %%
"""Dataset loader to feed into model."""
import mindspore as ms
import mindspore.dataset as ds

def load_dataset(input_file, batch_size: int, epoch_count: int,
                 sink_mode: bool, sink_step: int = 1, rank_size: int = 1, rank_id: int = 0, shuffle=True):

    print(f" | Loading {input_file}.")

    data_set = ds.MindDataset(
        input_file,
        columns_list=[
            "src", "src_padding",
            "prev_opt", "prev_padding",
            "target", "tgt_padding"
        ],
        shuffle=shuffle, num_shards=rank_size, shard_id=rank_id)

    type_cast_op = ds.transforms.transforms.TypeCast(ms.int32)
    data_set = data_set.map(operations=type_cast_op, input_columns="src")
    data_set = data_set.map(operations=type_cast_op, input_columns="src_padding")
    data_set = data_set.map(operations=type_cast_op, input_columns="prev_opt")
    data_set = data_set.map(operations=type_cast_op, input_columns="prev_padding")
    data_set = data_set.map(operations=type_cast_op, input_columns="target")
    data_set = data_set.map(operations=type_cast_op, input_columns="tgt_padding")


    ori_dataset_size = data_set.get_dataset_size()
    print(f" | Dataset size: {ori_dataset_size}.")
    repeat_count = epoch_count

    data_set = data_set.rename(
        input_columns=["src",
                       "src_padding",
                       "prev_opt",
                       "prev_padding",
                       "target",
                       "tgt_padding"],
        output_columns=["source_eos_ids",
                        "source_eos_mask",
                        "target_sos_ids",
                        "target_sos_mask",
                        "target_eos_ids",
                        "target_eos_mask"]
    )

    # apply batch operations
    data_set = data_set.batch(batch_size, drop_remainder=True)
    data_set = data_set.repeat(repeat_count)

    data_set.channel_name = 'transformer'
    return data_set

# %% [markdown]
# # pretraining

# %%
"""定义训练与推理的参数"""
import mindspore.common.dtype as mstype
class config():
    enable_modelarts = True #Whether training on modelarts, default = False
    device_target = "Ascend"
    output_path = "./output/"
    save_checkpoint_path = "./output/checkpoint/"
    checkpoint_file_path = ""
    # Training options
    epochs = 20
    batch_size = 192
    dtype = mstype.float32 #only support float16 and float32
    compute_type = mstype.float16 #only support float16 and float32
    pre_train_dataset = "./train_data/news_crawl/news2012_short_len_32.mindrecord"
    # ./train_data/news_crawl/news2012_len_32.tfrecord-001-of-001
    fine_tune_dataset = "./train_data/ggw_data/gigaword_train_dataset.mindrecord"
    test_dataset = "./train_data/ggw_data/gigaword_test_dataset.mindrecord"
    dataset_sink_mode = False
    dataset_sink_step = 100
    random_seed = 100
    save_graphs = False
    seq_length = 32 #64
    vocab_size = 0 #need change
    hidden_size = 1024
    num_hidden_layers = 6
    num_attention_heads = 8
    intermediate_size = 4096
    hidden_act = "relu"
    hidden_dropout_prob = 0.2
    attention_dropout_prob = 0.2
    max_position_embeddings = 32 #64
    initializer_range = 0.02
    label_smoothing = 0.1
    beam_width = 4
    length_penalty_weight = 1.0
    max_decode_length = 32 #64
    init_loss_scale = 65536
    loss_scale_factor = 2
    scale_window = 200
    lr = 0.0001
    poly_lr_scheduler_power = 0.5
    decay_steps = 10000
    decay_start_step = 12000
    warmup_steps = 4000
    min_lr = 0.000001
    save_ckpt_steps = 10000
    keep_ckpt_max = 50
    ckpt_prefix = "pt"
    metric = "rouge"
    vocab = "./vocab/all_en.dict.bin"
    output = "./output/infer.bin"

# %%
import os
import pickle
import numpy as np

from mindspore.common.tensor import Tensor
from mindspore.nn import Momentum
from mindspore.nn.optim import Adam, Lamb
from mindspore.train.model import Model
from mindspore.train.loss_scale_manager import DynamicLossScaleManager, FixedLossScaleManager
from mindspore.train.callback import CheckpointConfig, ModelCheckpoint, TimeMonitor
from mindspore import context, Parameter
from mindspore.communication import management as MultiAscend
from mindspore.train.serialization import load_checkpoint
from mindspore.common import set_seed

from src.transformer import TransformerNetworkWithLoss, TransformerTrainOneStepWithLossScaleCell
from src.utils import LossCallBack
from src.utils import one_weight, zero_weight, weight_variable
from src.utils import square_root_schedule
from src.utils.lr_scheduler import polynomial_decay_scheduler, BertLearningRate

# %%
config = config()
config.epochs = 1 #for test

vocab_path = './vocab/all_en.dict.bin'
vocab = Dictionary.load_from_persisted_dict(vocab_path)
config.vocab_size = vocab.size

print(" | Starting training on single device.")
pre_train_dataset = load_dataset(input_file=config.pre_train_dataset,
                                 batch_size=config.batch_size,
                                 epoch_count=1,
                                 sink_mode=config.dataset_sink_mode,
                                 sink_step=config.dataset_sink_step)

# 定义帶loss的網路
net_with_loss = TransformerNetworkWithLoss(config, is_training=True)
net_with_loss.init_parameters_data()

for param in net_with_loss.trainable_params():
    name = param.name
    value = param.data
    if isinstance(value, Tensor):
        if name.endswith(".gamma"):
            param.set_data(one_weight(value.asnumpy().shape))
        elif name.endswith(".beta") or name.endswith(".bias"):
            param.set_data(zero_weight(value.asnumpy().shape))
        else:
            param.set_data(weight_variable(value.asnumpy().shape))

update_steps = config.epochs * pre_train_dataset.get_dataset_size()

# 定义递减的学习率
lr = Tensor(polynomial_decay_scheduler(lr=config.lr,
           min_lr=config.min_lr,
           decay_steps=config.decay_steps,
           total_update_num=update_steps,
           warmup_steps=config.warmup_steps,
           power=config.poly_lr_scheduler_power), dtype=mstype.float32)
# 定义优化器
optimizer = Adam(net_with_loss.trainable_params(), lr, beta1=0.9, beta2=0.98)

# loss scale (mode = dynamic)
scale_manager = DynamicLossScaleManager(init_loss_scale=config.init_loss_scale,
                                        scale_factor=config.loss_scale_factor,
                                        scale_window=config.scale_window)
# 定义反向网络
net_with_grads = TransformerTrainOneStepWithLossScaleCell(network=net_with_loss, optimizer=optimizer,
                                                          scale_update_cell=scale_manager.get_update_cell())
net_with_grads.set_train(True)

# 初始化模型
model = Model(net_with_grads)

time_cb = TimeMonitor(data_size=pre_train_dataset.get_dataset_size())
ckpt_config = CheckpointConfig(save_checkpoint_steps=config.save_ckpt_steps,
                               keep_checkpoint_max=config.keep_ckpt_max)

callbacks = []
callbacks.append(time_cb)
ckpt_save_dir = config.save_checkpoint_path

ckpt_callback = ModelCheckpoint(
    prefix=config.ckpt_prefix,
    directory=os.path.join(ckpt_save_dir, 'ckpt_pt'),
    config=ckpt_config)
loss_monitor = LossCallBack(rank_id=0)
callbacks.append(loss_monitor)
callbacks.append(ckpt_callback)

print(" | Start pre-training job.")
model.train(config.epochs, pre_train_dataset,
            callbacks=callbacks, dataset_sink_mode=config.dataset_sink_mode,
            sink_size=config.dataset_sink_step)
# Out:
#  | Starting training on single device.
#  | Loading ./train_data/news_crawl/news2012_short_len_32.mindrecord.
#  | Dataset size: 999745.
# [WARNING] ME(35561:281473587120704,MainProcess):2024-01-11-23:16:08.639.534 [mindspore/train/model.py:1083] For LossCallBack callback, {'step_end'} methods may not be supported in later version, Use methods prefixed with 'on_train' or 'on_eval' instead when using customized callbacks.
#  | Start pre-training job.
# Train epoch time: 4965862.593 ms, per step time: 953.690 ms

# %% [markdown]
# # fine tuning
# # 修改 config.checkpoint_file_path = './output/checkpoint/ckpt_pt/pt-xxxx.ckpt'

# %%
"""定义训练与推理的参数"""
import mindspore.common.dtype as mstype
class config():
    enable_modelarts = True #Whether training on modelarts, default = False
    device_target = "Ascend"
    output_path = "./output/"
    save_checkpoint_path = "./output/checkpoint/"
    checkpoint_file_path = ""
    # Training options
    epochs = 20
    batch_size = 192
    dtype = mstype.float32 #only support float16 and float32
    compute_type = mstype.float16 #only support float16 and float32
    pre_train_dataset = "./train_data/news_crawl/news2012_short_len_32.mindrecord"
    # ./train_data/news_crawl/news2012_len_32.tfrecord-001-of-001
    fine_tune_dataset = "./train_data/ggw_data/gigaword_train_dataset.mindrecord"
    test_dataset = "./train_data/ggw_data/gigaword_test_dataset.mindrecord"
    dataset_sink_mode = False
    dataset_sink_step = 100
    random_seed = 100
    save_graphs = False
    seq_length = 32 #64
    vocab_size = 0 #need change
    hidden_size = 1024
    num_hidden_layers = 6
    num_attention_heads = 8
    intermediate_size = 4096
    hidden_act = "relu"
    hidden_dropout_prob = 0.2
    attention_dropout_prob = 0.2
    max_position_embeddings = 32 #64
    initializer_range = 0.02
    label_smoothing = 0.1
    beam_width = 4
    length_penalty_weight = 1.0
    max_decode_length = 32 #64
    init_loss_scale = 65536
    loss_scale_factor = 2
    scale_window = 200
    lr = 0.0001
    poly_lr_scheduler_power = 0.5
    decay_steps = 10000
    decay_start_step = 12000
    warmup_steps = 4000
    min_lr = 0.000001
    save_ckpt_steps = 10000
    keep_ckpt_max = 50
    ckpt_prefix = "ft"
    metric = "rouge"
    vocab = "./vocab/all_en.dict.bin"
    output = "./output/infer.bin"

# %%
config = config()
config.checkpoint_file_path = './output/checkpoint/ckpt_pt/pt-1_5207.ckpt' #赋值给预训练生成的已有模型文件
config.epochs = 1 #for test

vocab_path = './vocab/all_en.dict.bin'
vocab = Dictionary.load_from_persisted_dict(vocab_path)
config.vocab_size = vocab.size

print(" | Starting training on single device.")
fine_tune_dataset = load_dataset(input_file=config.fine_tune_dataset,
                                 batch_size=config.batch_size,
                                 epoch_count=1,
                                 sink_mode=config.dataset_sink_mode,
                                 sink_step=config.dataset_sink_step)

# 定义帶loss的網路
net_with_loss = TransformerNetworkWithLoss(config, is_training=True)
net_with_loss.init_parameters_data()

# 读取已有模型文件的权重
weights = load_checkpoint(config.checkpoint_file_path)
for param in net_with_loss.trainable_params():
    weights_name = param.name
    if isinstance(weights[weights_name], Parameter):
        param.set_data(weights[weights_name].data)
    elif isinstance(weights[weights_name], Tensor):
        param.set_data(Tensor(weights[weights_name].asnumpy(), config.dtype))
    elif isinstance(weights[weights_name], np.ndarray):
        param.set_data(Tensor(weights[weights_name], config.dtype))
    else:
        param.set_data(weights[weights_name])

update_steps = config.epochs * fine_tune_dataset.get_dataset_size()

# 定义递减的学习率
lr = Tensor(polynomial_decay_scheduler(lr=config.lr,
           min_lr=config.min_lr,
           decay_steps=config.decay_steps,
           total_update_num=update_steps,
           warmup_steps=config.warmup_steps,
           power=config.poly_lr_scheduler_power), dtype=mstype.float32)
# 定义优化器
optimizer = Adam(net_with_loss.trainable_params(), lr, beta1=0.9, beta2=0.98)

# loss scale (mode = dynamic)
scale_manager = DynamicLossScaleManager(init_loss_scale=config.init_loss_scale,
                                        scale_factor=config.loss_scale_factor,
                                        scale_window=config.scale_window)
# 定义反向网络
net_with_grads = TransformerTrainOneStepWithLossScaleCell(network=net_with_loss, optimizer=optimizer,
                                                          scale_update_cell=scale_manager.get_update_cell())
net_with_grads.set_train(True)

# 初始化模型
model = Model(net_with_grads)

time_cb = TimeMonitor(data_size=fine_tune_dataset.get_dataset_size())
ckpt_config = CheckpointConfig(save_checkpoint_steps=config.save_ckpt_steps,
                               keep_checkpoint_max=config.keep_ckpt_max)

callbacks = []
callbacks.append(time_cb)
ckpt_save_dir = config.save_checkpoint_path

ckpt_callback = ModelCheckpoint(
    prefix=config.ckpt_prefix,
    directory=os.path.join(ckpt_save_dir, 'ckpt_ft'),
    config=ckpt_config)
loss_monitor = LossCallBack(rank_id=0)
callbacks.append(loss_monitor)
callbacks.append(ckpt_callback)

print(" | Start fine-tuning job.")
model.train(config.epochs, fine_tune_dataset,
            callbacks=callbacks, dataset_sink_mode=config.dataset_sink_mode,
            sink_size=config.dataset_sink_step)
# Out:
#  | Starting training on single device.
#  | Loading ./train_data/ggw_data/gigaword_train_dataset.mindrecord.
#  | Dataset size: 194181.
# [WARNING] ME(35561:281473587120704,MainProcess):2024-01-12-00:48:49.181.132 [mindspore/train/model.py:1083] For LossCallBack callback, {'step_end'} methods may not be supported in later version, Use methods prefixed with 'on_train' or 'on_eval' instead when using customized callbacks.
#  | Start fine-tuning job.
# Train epoch time: 991487.919 ms, per step time: 980.700 ms

# %% [markdown]
# # test
# # 修改 config.checkpoint_file_path = "./output/checkpoint/ckpt_ft/ft-xxxx.ckpt"

# %%
"""定义训练与推理的参数"""
import mindspore.common.dtype as mstype
class config():
    enable_modelarts = True #Whether training on modelarts, default = False
    device_target = "Ascend"
    output_path = "./output/"
    save_checkpoint_path = "./output/checkpoint/"
    checkpoint_file_path = ""
    # Training options
    epochs = 20
    batch_size = 192
    dtype = mstype.float32 #only support float16 and float32
    compute_type = mstype.float16 #only support float16 and float32
    pre_train_dataset = "./train_data/news_crawl/news2012_short_len_32.mindrecord"
    # ./train_data/news_crawl/news2012_len_32.tfrecord-001-of-001
    fine_tune_dataset = "./train_data/ggw_data/gigaword_train_dataset.mindrecord"
    test_dataset = "./train_data/ggw_data/gigaword_test_dataset.mindrecord"
    dataset_sink_mode = False
    dataset_sink_step = 100
    random_seed = 100
    save_graphs = False
    seq_length = 32 #64
    vocab_size = 0 #need change
    hidden_size = 1024
    num_hidden_layers = 6
    num_attention_heads = 8
    intermediate_size = 4096
    hidden_act = "relu"
    hidden_dropout_prob = 0.2
    attention_dropout_prob = 0.2
    max_position_embeddings = 32 #64
    initializer_range = 0.02
    label_smoothing = 0.1
    beam_width = 4
    length_penalty_weight = 1.0
    max_decode_length = 32 #64
    init_loss_scale = 65536
    loss_scale_factor = 2
    scale_window = 200
    lr = 0.0001
    poly_lr_scheduler_power = 0.5
    decay_steps = 10000
    decay_start_step = 12000
    warmup_steps = 4000
    min_lr = 0.000001
    save_ckpt_steps = 10000
    keep_ckpt_max = 50
    ckpt_prefix = "ft"
    metric = "rouge"
    vocab = "./vocab/all_en.dict.bin"
    output = "./output/infer.bin"

# %%
import os
import pickle
import time

import mindspore.nn as nn
import mindspore.common.dtype as mstype
from mindspore.ops import operations as P
from mindspore.common.tensor import Tensor
from mindspore.train.model import Model
from mindspore.train.serialization import load_checkpoint, load_param_into_net

from src.utils import Dictionary
from src.transformer.transformer_for_infer import TransformerInferModel
from src.transformer.transformer_for_train import TransformerTraining
from src.utils.load_weights import load_infer_weights
from src.utils.rouge_score import rouge

class TransformerInferCell(nn.Cell):
    def __init__(self, network):
        super(TransformerInferCell, self).__init__(auto_prefix=False)
        self.network = network

    def construct(self,
                  source_ids,
                  source_mask):
        predicted_ids, predicted_probs = self.network(source_ids,
                                                      source_mask)
        return predicted_ids, predicted_probs

def get_rouge_score(result, vocab):
    """Calculate ROUGE score."""
    predictions = []
    targets = []
    for sample in result:
        predictions.append(' '.join([vocab[t] for t in sample['prediction']]))
        targets.append(' '.join([vocab[t] for t in sample['target']]))
        print(f" | source: {' '.join([vocab[t] for t in sample['source']])}")
        print(f" | prediction: {predictions[-1]}")
        print(f" | target: {targets[-1]}")

    return rouge(predictions, targets)

config = config()
config.epoch = 1 #for test
#这个文件名称要修改为训练好的模型文件路径
config.checkpoint_file_path = "./output/checkpoint/ckpt_ft/ft-1_1011.ckpt"

vocab_path = './vocab/all_en.dict.bin'
vocab = Dictionary.load_from_persisted_dict(vocab_path)
config.vocab_size = vocab.size

eval_dataset = load_dataset(input_file=config.test_dataset,
                            batch_size=config.batch_size,
                            epoch_count=1,
                            sink_mode=config.dataset_sink_mode,
                            shuffle=False)

tfm_model = TransformerInferModel(config=config, use_one_hot_embeddings=False)
tfm_model.init_parameters_data()

params = tfm_model.trainable_params()
weights = load_infer_weights(config)

for param in params:
    value = param.data
    name = param.name
    with open("weight_after_deal.txt", "a+") as f:
        weights_name = name
        f.write(weights_name + "\n")
        if isinstance(value, Tensor):
            if weights_name in weights:
                assert weights_name in weights
                param.set_data(Tensor(weights[weights_name], mstype.float32))

print(" | Load weights successfully.")

tfm_infer = TransformerInferCell(tfm_model)
model = Model(tfm_infer)

predictions = []
probs = []
source_sentences = []
target_sentences = []
for batch in eval_dataset.create_dict_iterator(output_numpy=True, num_epochs=1):
    source_sentences.append(batch["source_eos_ids"])
    target_sentences.append(batch["target_eos_ids"])

    source_ids = Tensor(batch["source_eos_ids"], mstype.int32)
    source_mask = Tensor(batch["source_eos_mask"], mstype.int32)

    start_time = time.time()
    predicted_ids, entire_probs = model.predict(source_ids, source_mask)
    print(f" | Batch size: {config.batch_size}, "
          f"Time cost: {time.time() - start_time}.")

    predictions.append(predicted_ids.asnumpy())
    probs.append(entire_probs.asnumpy())

output = []
for inputs, ref, batch_out, batch_probs in zip(source_sentences,
                                               target_sentences,
                                               predictions,
                                               probs):
    for i in range(config.batch_size):
        if batch_out.ndim == 3:
            batch_out = batch_out[:, 0]

        example = {
            "source": inputs[i].tolist(),
            "target": ref[i].tolist(),
            "prediction": batch_out[i].tolist(),
            "prediction_prob": batch_probs[i].tolist()
        }
        output.append(example)

with open(config.output, "wb") as f:
    pickle.dump(output, f, 1)

score = get_rouge_score(output, vocab)
print(score)
# Out:
#  | Loading ./train_data/ggw_data/gigaword_test_dataset.mindrecord.
#  | Dataset size: 1081.
#  | Load weights successfully.
#  | Batch size: 192, Time cost: 1652.7519772052765.
#  | Batch size: 192, Time cost: 28.484652042388916.
#  | Batch size: 192, Time cost: 6.254255533218384.
#  | Batch size: 192, Time cost: 6.127770900726318.
#  | Batch size: 192, Time cost: 6.0402281284332275.
#  | source: japan 's nec corp. and UNK computer corp. of the united states said wednesday they had agreed to join forces in <unk> sales . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: nec UNK in computer sales tie-up </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: the sri <unk> government on wednesday announced the closure of government schools with immediate effect as a military campaign against <unk> separatists escalated in the north of the country . </s> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: sri <unk> closes schools as war escalates </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: police arrested five anti-nuclear protesters thursday after they sought to disrupt loading of a french antarctic research and supply vessel , a spokesman for the protesters said . </s> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: protesters target french research ship </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: factory orders for manufactured goods rose <unk> percent in <unk> , the commerce department said here thursday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: us <unk> factory orders up <unk> percent </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: the bank of japan appealed to financial markets to remain calm friday following the us decision to order <unk> bank <unk> to close its us operations . </s> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: bank of UNK UNK for calm in financial markets </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: russian liberal party wins registration </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: turnout was heavy for parliamentary elections monday in <unk> and <unk> after a month of intensive campaigning throughout the country , one of the most prosperous in the caribbean . </s> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> and <unk> poll draws heavy turnout by john <unk> </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: jordan 's crown prince hassan ibn <unk> arrived tuesday for his first visit to jerusalem and was to pay his condolences to the widow of assassinated prime minister <unk> rabin . </s>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: jordan 's crown prince makes first visit to jerusalem </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> 's main opposition party tuesday endorsed president lech <unk> in an upcoming presidential run-off election after a reformed communist won the first round of voting . </s> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> receives opposition boost </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: the rand gained ground against the dollar at the opening here wednesday , to <unk> <unk> <unk> to the greenback from <unk> <unk> <unk> at the close tuesday . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: rand gains ground </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: hong kong signed a breakthrough air services agreement with the united states on friday that will allow us airlines to carry freight to asian destinations via the territory . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: hong kong us sign breakthrough aviation pact </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: a us citizen who spied for communist east germany was given a suspended jail sentence of <unk> months here friday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: us citizen who spied for east <unk> given suspended sentence </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: france , still high after their convincing <unk> win over new zealand have named the same team for the second test next saturday in paris . </s> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: french keep same team for <unk> test </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> quarter : chi - <unk> , <unk> <unk> <unk> UNK pass from <unk> <unk> <unk> kevin butler kick <unk> , <unk> . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: chicago # <unk> # # <unk> green bay <unk> # # # <unk> </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: at least <unk> people were killed when a nigeria airways airliner crashed on landing monday at <unk> airport in the north of the country , airport officials said . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> plane crashes on landing killing at least <unk> </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: roh <unk> , the former south korean military UNK charged with corruption on thursday , oversaw the first tentative steps of his country 's transition from authoritarian rule to democracy . </s>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: roh coup <unk> then democracy convert now in disgrace by UNK park </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: a court here thursday sentenced a <unk> man to <unk> years in jail after he admitted <unk> his baby son to death to silence him while watching television . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: man who killed baby to hear television better gets <unk> years </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: five east <unk> youths who scaled the french embassy 's fence here thursday , left the embassy on their way to portugal friday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: UNK latest east <unk> asylum seekers leave for portugal </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: the repatriation of at least <unk> <unk> <unk> was postponed friday after the <unk> pulled out of the first joint scheme to return refugees to their homes in northwest <unk> . </s>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: repatriation of <unk> refugees postponed </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: outgoing polish president lech <unk> and his ex-communist rival <unk> <unk> cast their ballots sunday in a tight contest for the presidency but managed some humor amid all the tension . </s>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> <unk> cast ballot amid touch of humor </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: tea scores on the fourth day of the second test between australia and <unk> here monday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: australia vs <unk> tea scorecard </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: the head of the <unk> government in the breakaway republic of <unk> narrowly survived a bomb attack monday , the third assassination attempt against top russian officials in two months . </s>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: head of UNK <unk> government survives bomb </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: former israeli chief of staff <unk> <unk> is to be appointed foreign minister in the new cabinet of prime minister <unk> peres , an outgoing minister said tuesday . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> to be named israel 's new fm outgoing minister says </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: president <unk> <unk> in nigeria </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> prime minister <unk> <unk> indicated friday he would soon <unk> control of the ruling party to his deputy anwar <unk> . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> wants leadership change to be smooth </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: ministers from the european union and its <unk> neighbors gathered here under heavy security on monday for an unprecedented conference on economic and political cooperation . </s> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: european <unk> ministers gather for landmark conference by <unk> <unk> </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> telecommunications giant <unk> has reached a basic agreement to sell its relay production to japanese electronics company UNK corp , <unk> said thursday . </s> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> sells relay production to UNK 's UNK corp </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: russian foreign minister <unk> <unk> on thursday welcomed a us move to enter <unk> talks on iran 's nuclear program , urging the international community not to disrupt the process . </s>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: russia urges international community not to disrupt iran talks UNK picture </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: football fans in the <unk> capital <unk> will be able to watch the world cup live on big screens at <unk> city locations , officials said friday . </s> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: the <unk> world news summary </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> won the toss and chose to bat on the opening day in the opening test against west indies at the <unk> recreation ground on friday . </s> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> win toss and elect to bat in first test </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: polling stations closed at <unk> <unk> <unk> <unk> local time <unk> friday on the first day of czech legislative elections <unk> by allegations surrounding social democrat prime minister <unk> <unk> . </s>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: polling stations close on first day of czech legislative elections </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: an <unk> indian state is paying handsome rewards to policemen for slaying <unk> rebels in the <unk> despite protests from rights groups about <unk> violence . </s> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: police turn UNK in <unk> indian state by UNK UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: the united nations condemned saturday an attack on russian embassy employees in <unk> that claimed the life of one russian and resulted in the kidnapping of four others . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: un condemns murder UNK of <unk> in iraq UNK UNK UNK with annan comment </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: american <unk> specialist david <unk> of team <unk> won the <unk> km opening <unk> of the <unk> <unk> here on sunday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: american <unk> <unk> <unk> <unk> </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: a powerful bomb exploded outside a navy base near the sri <unk> capital <unk> tuesday , seriously wounding at least one person , military officials said . </s> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: bomb attack outside <unk> navy base </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: chelsea manager jose <unk> has said that only another title and the champions league will <unk> for him as he builds towards next season . </s> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> targets second champions league crown UNK UNK details </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: russia warned wednesday against nato taking in the <unk> republics of <unk> and <unk> , saying such a colossal geopolitical shift would threaten relations . </s> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: russia warns of colossal impact if nato takes in <unk> <unk> UNK UNK quote </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> steel said on wednesday that its hostile takeover offer to shareholders in european steelmaker <unk> had officially begun in the united states and would last until <unk> # . </s> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> launches hostile <unk> bid in us </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: americans have to wait probably another year before they can relish <unk> indian <unk> . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: time not ripe yet for indian <unk> to hit us </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: earthquake survivors on <unk> 's java island have endured <unk> suffering but some say they are now facing the final straw : missing out on watching the world cup . </s> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> quake survivors brace for another hardship : no world cup by <unk> UNK UNK picture </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: even some of his rivals in the roland <unk> <unk> are hoping that roger <unk> can create a bit of tennis history by winning all four grand slams . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: even fellow players keen for <unk> grand slam dream UNK picture </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: question marks over the form of spain 's record <unk> captain raul continued to feed the concerns of the country 's press here friday . </s> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: pressure on raul as spain begin countdown by justin davis UNK picture </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: group of eight finance ministers warned saturday that the world economy was <unk> by soaring energy costs and called for closer cooperation to calm volatile oil and gas markets . </s> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> ministers warn of energy risks seek cooperative action by <unk> <unk> UNK picture UNK UNK with final statement </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: england coach <unk> <unk> believes his team must improve on their disappointing display against <unk> if they want to win the world cup . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: we must improve : <unk> by martin <unk> UNK picture </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> president <unk> abbas needs to do more to disarm militant groups , israeli prime minister <unk> <unk> said sunday , pledging to help in the process . </s> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: israel pm says abbas must do more to disarm militants UNK UNK detail UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: group h favorites spain could be given an unexpected boost ahead of their opener against <unk> - if <unk> <unk> decides to sit out wednesday 's afternoon match in <unk> . </s>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: doubts over raul and <unk> set to favor spain by justin davis UNK picture </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> <unk> scored twice as the czech republic enjoyed an impressive <unk> victory over the united states in their world cup opener on monday . </s> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> double gives <unk> winning start by jim <unk> UNK picture UNK UNK <unk> and arena UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: the open square in front of the french capital 's famed <unk> <unk> cathedral will be renamed after late pope john paul ii , the city council decided tuesday . </s> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> <unk> cathedral square to be named after john paul ii </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: the french press on wednesday were typically scathing in their assessment of les <unk> ' performance in their opening world cup match , a <unk> draw with <unk> . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: press <unk> sorry french display </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: press freedom in <unk> remains at risk despite the release on wednesday of prominent newspaper editor <unk> UNK after a two-year prison sentence , human rights organizations said . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> press freedom at risk despite editor 's release UNK picture </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: former italian prime minister silvio <unk> has been re-elected as president of serie a side ac <unk> , the club confirmed on thursday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> re-elected ac <unk> president </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: one of <unk> 's hottest actors john <unk> has refused to bow to pressure from <unk> 's health minister and quit promoting <unk> drinks . </s> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> <unk> at government over <unk> drink ad comments UNK picture </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: european union leaders gave <unk> a green light friday to join the eurozone next year , launching a new wave of expansion for the currently <unk> single currency club . </s> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: eu gives <unk> green light to join eurozone by <unk> thomas UNK picture UNK UNK UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: mauritania 's ruling military leaders have launched an electoral campaign in support of a constitutional referendum set for june <unk> , the official media announced friday . </s> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: mauritania 's junta campaigns for constitutional referendum </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> nations sent japan crashing to a third straight defeat on saturday at world whale talks soured by rows over cruelty and the moratorium on commercial hunts . </s> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: fierce rows rock world whaling talks by <unk> UNK UNK UNK UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: result in a world cup group g match here on sunday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: world cup : france # south korea # </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> on ivory coast who play <unk> and <unk> in a world cup group c match here on wednesday : UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: world cup <unk> <unk> : ivory coast </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: germany are renowned as masters in the penalty shootout but manager <unk> <unk> revealed monday that the world cup hosts have not been <unk> UNK in training . </s> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: germany not <unk> <unk> says <unk> UNK picture </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> <unk> <unk> arabia in their crunch group h game here monday , firmly setting their <unk> world cup campaign back on track with a convincing <unk> win . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> <unk> <unk> arabia for vital world cup win by <unk> <unk> UNK picture UNK UNK UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> on croatia who face australia in a world cup group f match here on thursday : UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: world cup <unk> <unk> : croatia </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> will miss their traditional <unk> <unk> in state-owned forests this year after the authorities on tuesday banned the practice because of risk of forest fires . </s> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> fest <unk> banned in <unk> forests </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: journalists and legislators in afghanistan have been outraged by the intelligence service 's new media guidelines that bar interviews with taliban leaders and criticism of foreign troops . </s> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: alarm over afghan guidelines for journalists by UNK <unk> </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: south korea said wednesday it would consider scrapping food aid to impoverished north korea if <unk> <unk> a missile . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> could UNK food aid if <unk> fires missile UNK UNK aid details minister quote </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: around <unk> clandestine immigrants wednesday staged a peaceful breakout from a detention center in malta and demonstrated on a road shouting `` we want freedom . </s> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: mass breakout of immigrants from malta center </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: like a <unk> army , south korea are marching towards the <unk> stages of the <unk> world cup on their <unk> . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: team korea marching on their <unk> </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: hong kong flag carrier <unk> pacific said thursday it has ordered six <unk> UNK freighter aircraft in a billion dollar deal for delivery between may <unk> and april <unk> . </s> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> orders six <unk> <unk> freighter planes UNK UNK details UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: fbi agents have arrested at least seven people in miami who reportedly plotted to attack the chicago <unk> tower <unk> , according to official statements and news reports . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: fbi arrests seven in UNK plot on chicago <unk> tower UNK correction please read <unk> seas of david <unk> sted of cs of david in UNK <unk> </s> <pad> <pad> <pad> <pad>
#  | source: world cup hopefuls spain secured their objective of finishing top of group h with a <unk> <unk> win over whipping boys <unk> arabia here on friday . </s> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: fans feel the pain as spain beat <unk> by justin davis UNK picture </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: teenager <unk> <unk> claimed her first <unk> title with a <unk> , <unk> victory over third seed <unk> <unk> at home in the <unk> UNK open on saturday . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> defeats <unk> in dutch final UNK picture </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: a japanese man hanged himself in taiwan sunday after the asian champions failed to secure a single victory in the world cup , a report said . </s> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: UNK fan hangs himself for nation 's dismal world cup performance : report </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: france beat south africa <unk> here on sunday to become the world <unk> rugby champions for the first time . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: france crowned world <unk> rugby champions UNK UNK UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: china has executed five people who had been sentenced to death for drugs trafficking , state media reported on monday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: china says five executed for drugs </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> moved to consolidate their premiership status tuesday by tying down one of the brightest stars of last season 's maiden top flight campaign . </s> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> tie up <unk> for three years </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: a controversial civilian nuclear energy deal between <unk> and the united states cleared its first major hurdle tuesday , easily winning approval by a us congress committee . </s> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: us congress committee backs nuclear deal with <unk> UNK UNK UNK UNK detail </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: chinese government departments lost <unk> billion dollars last year through corruption , poor tax methods and bad land management , the national audit office said in a report published wednesday . </s>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: china audit finds widespread corruption tax losses in government UNK UNK report details budget UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: the <unk> martyrs brigades said wednesday it had kidnapped an israeli settler , marking the third abduction of an israeli since sunday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> claims abduction of third israeli UNK UNK <unk> statement </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: greece said thursday that it was monitoring the escalating hostilities between <unk> and <unk> with `` particular concern , '' and feared it could worsen . </s> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: greece worried over escalation of <unk> hostilities </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: european stock markets advanced strongly thursday on some bargain-hunting and gains by wall street and japanese shares ahead of an expected hike in us interest rates , dealers said . </s> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: european stocks bounce back UNK UNK with closing levels </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> prime minister ismail <unk> insisted friday that his <unk> government was continuing efforts to secure the release of an israeli soldier captured by militants . </s> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: efforts still underway to secure soldier 's release : hamas pm </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: the united states deported to <unk> on friday two <unk> <unk> wanted by a local court on charges of genocide committed in the <unk> <unk> massacre , an official said . </s>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: us deports to <unk> two <unk> wanted for <unk> genocide </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> <unk> scored twice as italy beat <unk> <unk> in the world cup quarter-finals here on friday to set up a <unk> last four clash against hosts germany . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: terrific <unk> seals semi-final place for italy by <unk> UNK UNK picture </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: up to <unk> <unk> packed <unk> 's streets to celebrate the gay and lesbian <unk> gras , breaking attendance records for the eye - popping annual street festival . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> 's gay and lesbian <unk> gras draws record-breaking crowd UNK pictures </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: the head of <unk> , the top sunni <unk> authority , will visit germany next week to discuss the teaching of <unk> in europe , his spokesman said monday . </s> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
# ...
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: sri <unk> pm to meet us president to review peace process </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> 's top shares prices ended higher monday as rumors indicating a swift sell-off concerning state-run oil major <unk> state oil <unk> <unk> <unk> . </s> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> stocks close up </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: south korean stocks continued their winning streak on foreign and program buying , with the main index bouncing back to the <unk> level on tuesday . </s> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: s. korean stocks continue rising </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> president <unk> <unk> wednesday spoke highly of the <unk> relations , saying that the relations between the two countries are always excellent , strategic and permanent . </s> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: interview : <unk> relations are excellent strategic permanent : <unk> by <unk> UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: following are the schedule for the world cup volleyball from <unk> # in <unk> japanese cities : UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: schedule of world cup volleyball UNK women </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: truck drivers and mechanics working for waste management inc. returned to work thursday after a two-week strike in los angeles , organizers said . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: trash workers end strike in los angeles </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: hosts <unk> won the men 's soccer title by beating <unk> <unk> <unk> here at the <unk> chinese city games on friday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: hosts <unk> wins men 's soccer title at chinese city games </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: in anticipation of strong winds returning , fire departments across southern california are bracing for a possible new round of fresh wildfires , authorities said on friday . </s> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> : firefighters gear up for fresh fires in s. california </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: chief of army staff of <unk> general <unk> <unk> on saturday declared a state of emergency in the country , the state-run <unk> reported . </s> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> ld : <unk> declares state of emergency in <unk> </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: strengthened border patrol has led to a <unk> drop in arrests of undocumented migrants this year at the <unk> frontier , it was reported on wednesday . </s> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: arrests of <unk> drop </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> 's biggest mining company said it will spill out # billion u.s. dollars for its three-year expansion scheme , daily mail reported on friday . </s> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> 's biggest miner to spend # bln dollars on expansion </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: a landslide in northwest china 's <unk> province has trapped three people since saturday , the local government said on sunday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: landslide UNK three in northwest china </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: six people were confirmed dead and two others were hospitalized in a food poisoning case on sunday in central china 's <unk> province , local government sources said on monday . </s>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: major news items in leading indian UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: brazilian <unk> was reported for training with <unk> on tuesday with a twisted ankle , team doctor jose luis <unk> said . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> trains with ankle injury for <unk> </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: a <unk> fishing vessel , which has been captured off the <unk> coast in may and released early this month , arrived at <unk> port of <unk> on wednesday . </s> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> fishing vessel released off <unk> coast arrives at <unk> <unk> </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> stocks opened sharply lower friday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: major news items in leading new zealand UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: coach of manchester city football club <unk> <unk> signed three thai young players to the english premiership league team at a ceremony in <unk> friday morning . </s> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: UNK man </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: china 's sun hui claimed gold in the women 's <unk> <unk> at the <unk> world <unk> championships here on saturday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: china 's sun wins women 's <unk> of <unk> at world <unk> championships </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: <unk> has imported about <unk> tons of maize from <unk> and more tons are lined up for <unk> , according sunday mail . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: head-to-head record for <unk> masters cup final </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: the death toll from the last thursday night 's cyclone in <unk> shot up to <unk> till <unk> p. m. monday , according to the food and disaster management ministry . </s>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: cyclone death toll in <unk> rises to <unk> </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: nigeria 's federal capital <unk> on monday got the hosting right of the sixth students for the <unk> of global <unk> <unk> <unk> <unk> world cup tournament . </s> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: nigeria to host <unk> <unk> world cup </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: expensive scientific instruments are now available for public rental throughout china via a new <unk> database launched on thursday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: foreign exchange rates in <unk> </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: romania and <unk> will cooperate in transporting <unk> oil to european consumer markets , the <unk> and <unk> presidents stressed in a joint press statement on thursday . </s> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: romania <unk> to cooperate in transporting oil </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: between <unk> and <unk> people in vietnam die of diseases caused by smoking each year , according to local newspaper youth on monday . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> <unk> <unk> die from smoking annually </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: by <unk> writer jiang UNK , <unk> UNK UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> UNK focus : china france sign <unk> nuclear energy deal </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: a <unk> <unk> earthquake rocked metro manila at around <unk> p.m. tuesday but there is no immediate reports of casualties . </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> ld UNK : earthquake hits metro manila </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: UNK </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: <unk> ld : <unk> 's <unk> steps down as army chief </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | source: jing <unk> , commander of the second artillery force of the chinese people 's liberation army <unk> <unk> <unk> , wrapped up his official visit to sweden wednesday . </s> <pad> <pad>
#  | prediction: <s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>
#  | target: senior chinese military official UNK up visit to sweden </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  | ROUGE Score:
#  | RG-1(F):     0.09
#  | RG-2(F):     0.00
#  | RG-L(F):     0.09
# None
